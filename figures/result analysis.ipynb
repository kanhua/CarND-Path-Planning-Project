# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

ms_to_mph=2.23694

# %%
smat=np.loadtxt("over_speed_log.txt",delimiter=',')

# %%
plt.plot(smat[:,1])
plt.plot(smat[:,2])
plt.grid()
